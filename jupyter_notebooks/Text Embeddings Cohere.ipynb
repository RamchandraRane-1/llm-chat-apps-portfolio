# %%
pip install langchain-cohere -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-cohere in c:\users\ranes\appdata\roaming\python\python312\site-packages (0.4.4)
# Requirement already satisfied: cohere<6.0,>=5.12.0 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from langchain-cohere) (5.15.0)
# Collecting langchain-community<0.4.0,>=0.3.0 (from langchain-cohere)
#   Using cached langchain_community-0.3.25-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-core<0.4.0,>=0.3.27 (from langchain-cohere)
#   Using cached langchain_core-0.3.65-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from langchain-cohere) (2.8.2)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from langchain-cohere) (6.0.12.20250516)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from cohere<6.0,>=5.12.0->langchain-cohere) (1.11.1)
# Requirement already satisfied: httpx>=0.21.2 in c:\programdata\anaconda3\lib\site-packages (from cohere<6.0,>=5.12.0->langchain-cohere) (0.27.0)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from cohere<6.0,>=5.12.0->langchain-cohere) (0.4.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in c:\programdata\anaconda3\lib\site-packages (from cohere<6.0,>=5.12.0->langchain-cohere) (2.20.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from cohere<6.0,>=5.12.0->langchain-cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from cohere<6.0,>=5.12.0->langchain-cohere) (0.21.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from cohere<6.0,>=5.12.0->langchain-cohere) (2.32.4.20250611)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from cohere<6.0,>=5.12.0->langchain-cohere) (4.11.0)
# Collecting langchain<1.0.0,>=0.3.25 (from langchain-community<0.4.0,>=0.3.0->langchain-cohere)
#   Using cached langchain-0.3.25-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\programdata\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-cohere) (2.0.34)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-cohere) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-cohere) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-cohere) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-cohere) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-cohere) (2.6.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-cohere) (0.1.147)
# Requirement already satisfied: numpy>=1.26.2 in c:\programdata\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-cohere) (1.26.4)
# Collecting langsmith<0.4,>=0.1.125 (from langchain-community<0.4.0,>=0.3.0->langchain-cohere)
#   Using cached langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-cohere) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-cohere) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-cohere) (0.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (0.9.0)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.12.0->langchain-cohere) (4.2.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.12.0->langchain-cohere) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.12.0->langchain-cohere) (1.0.2)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.12.0->langchain-cohere) (3.7)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.12.0->langchain-cohere) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0,>=5.12.0->langchain-cohere) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-cohere) (2.1)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain<1.0.0,>=0.3.25->langchain-community<0.4.0,>=0.3.0->langchain-cohere)
#   Using cached langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.12.0->langchain-cohere) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.12.0->langchain-cohere) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (3.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\ranes\appdata\roaming\python\python312\site-packages (from tokenizers<1,>=0.15->cohere<6.0,>=5.12.0->langchain-cohere) (0.32.5)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.12.0->langchain-cohere) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.12.0->langchain-cohere) (2024.6.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.12.0->langchain-cohere) (4.66.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-cohere) (1.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.12.0->langchain-cohere) (0.4.6)
# Using cached langchain_community-0.3.25-py3-none-any.whl (2.5 MB)
# Using cached langchain_core-0.3.65-py3-none-any.whl (438 kB)
# Using cached langchain-0.3.25-py3-none-any.whl (1.0 MB)
# Using cached langsmith-0.3.45-py3-none-any.whl (363 kB)
# Using cached langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Installing collected packages: langsmith, langchain-core, langchain-text-splitters, langchain, langchain-community
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.1.147
#     Uninstalling langsmith-0.1.147:
#       Successfully uninstalled langsmith-0.1.147
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.53
#     Uninstalling langchain-core-0.1.53:
#       Successfully uninstalled langchain-core-0.1.53
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.0.2
#     Uninstalling langchain-text-splitters-0.0.2:
#       Successfully uninstalled langchain-text-splitters-0.0.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.13
#     Uninstalling langchain-0.1.13:
#       Successfully uninstalled langchain-0.1.13
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.38
#     Uninstalling langchain-community-0.0.38:
#       Successfully uninstalled langchain-community-0.0.38
# Successfully installed langchain-0.3.25 langchain-community-0.3.25 langchain-core-0.3.65 langchain-text-splitters-0.3.8 langsmith-0.3.45
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.1.0 requires langchain-core<0.2.0,>=0.1.33, but you have langchain-core 0.3.65 which is incompatible.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("COHERE_API_KEY")

# %%
from langchain_cohere import CohereEmbeddings

# %%
embeddings = CohereEmbeddings(model="embed-english-v3.0")

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\ranes\Downloads\Data.xlsx")
print(df)
# Out:
#          Words
# 0     Elephant
# 1         Lion
# 2        Tiger
# 3          Dog
# 4      Cricket
# 5      Footbal
# 6       Tennis
# 7   Basketball
# 8        Apple
# 9       Orange
# 10      Banana

# %%
df['embedding'] = df['Words'].apply(lambda x: embeddings.embed_query(text=x))
df.to_csv('word_embeddings.csv')

# %%
new_df = pd.read_csv('word_embeddings.csv')
print(new_df)
# Out:
#     Unnamed: 0       Words                                          embedding
# 0            0    Elephant  [-0.010971069, 0.009307861, -0.03225708, 0.001...
# 1            1        Lion  [0.012771606, -0.0064468384, -0.024215698, -0....
# 2            2       Tiger  [0.012130737, -0.021377563, -0.009941101, -0.0...
# 3            3         Dog  [0.0234375, -0.011428833, -0.027069092, -0.024...
# 4            4     Cricket  [-0.011634827, -0.03463745, -0.0034484863, -0....
# 5            5     Footbal  [-0.02835083, -0.010169983, 0.007259369, 0.011...
# 6            6      Tennis  [0.042785645, -0.023605347, 0.00025701523, -0....
# 7            7  Basketball  [0.047180176, -0.009475708, 0.0004506111, -0.0...
# 8            8       Apple  [0.0052261353, -0.0031147003, -0.058532715, -0...
# 9            9      Orange  [0.015548706, 0.00969696, -0.0055122375, -0.02...
# 10          10      Banana  [0.012046814, -0.01701355, -0.018051147, -0.03...

# %%
our_Text = "Cat"

# %%
text_embedding = embeddings.embed_query(our_Text)

# %%
 0.036193848, 0.0029659271, -0.0038528442, -0.01146698, -0.0033130646, -0.06689453, 0.030166626, -0.06500244, -0.0041656494, -0.010597229, -0.02218628, -0.028289795, 0.026901245, 0.028503418, 0.04168701, -0.013534546, -0.0102005005, 0.037902832, -0.013244629, -0.033966064, -0.018692017, -0.026779175, -0.027679443, 0.050567627, -0.04006958, -0.0036087036, 0.040618896, 0.064086914, -0.016601562, 0.014579773, 0.011711121, -0.027496338, 0.031707764, 0.026290894, 0.00038838387, -0.022079468, 0.029266357, -0.030578613, 0.0026054382, -0.046905518, 0.016555786, -0.0076141357, -0.041992188, 0.004673004, 0.0061912537, -0.00010883808, -0.045684814, 0.021057129, -0.002494812, -0.009712219, -0.017532349, 0.020523071, 0.027633667, -0.06137085, 0.01852417, 0.006362915, -0.007133484, -0.0049438477, 0.027755737, 0.030929565, 0.0007710457, 0.015426636, 0.04562378, 0.028900146, 0.004043579, -0.033935547, 0.08416748, 0.076293945, 0.06213379, 0.0017023087, -0.0075798035, -0.012908936, 0.06225586 ...

# %%
import numpy as np
def cosine_similarity(a,b):
    return np.dot(a,b) / (np.linalg.norm(a) * np.linalg.norm(b))
df['similarity score'] = df['embedding'].apply(lambda x: cosine_similarity(x, text_embedding))
df
# Out:
#          Words                                          embedding  \
# 0     Elephant  [-0.010971069, 0.009307861, -0.03225708, 0.001...
# 1         Lion  [0.012771606, -0.0064468384, -0.024215698, -0....
# 2        Tiger  [0.012130737, -0.021377563, -0.009941101, -0.0...
# 3          Dog  [0.0234375, -0.011428833, -0.027069092, -0.024...
# 4      Cricket  [-0.011634827, -0.03463745, -0.0034484863, -0....
# 5      Footbal  [-0.02835083, -0.010169983, 0.007259369, 0.011...
# 6       Tennis  [0.042785645, -0.023605347, 0.00025701523, -0....
# 7   Basketball  [0.047180176, -0.009475708, 0.0004506111, -0.0...
# 8        Apple  [0.0052261353, -0.0031147003, -0.058532715, -0...
# 9       Orange  [0.015548706, 0.00969696, -0.0055122375, -0.02...
# 10      Banana  [0.012046814, -0.01701355, -0.018051147, -0.03...
#
#     similarity score
# 0           0.544808
# 1           0.618015
# 2           0.629495
# 3           0.656284
# 4           0.425354
# 5           0.308218
# 6           0.447872
# 7           0.441999
# 8           0.589813
# 9           0.516904
# 10          0.523672

# %%
df.sort_values("similarity score", ascending = False).head(10)
# Out:
#          Words                                          embedding  \
# 3          Dog  [0.0234375, -0.011428833, -0.027069092, -0.024...
# 2        Tiger  [0.012130737, -0.021377563, -0.009941101, -0.0...
# 1         Lion  [0.012771606, -0.0064468384, -0.024215698, -0....
# 8        Apple  [0.0052261353, -0.0031147003, -0.058532715, -0...
# 0     Elephant  [-0.010971069, 0.009307861, -0.03225708, 0.001...
# 10      Banana  [0.012046814, -0.01701355, -0.018051147, -0.03...
# 9       Orange  [0.015548706, 0.00969696, -0.0055122375, -0.02...
# 6       Tennis  [0.042785645, -0.023605347, 0.00025701523, -0....
# 7   Basketball  [0.047180176, -0.009475708, 0.0004506111, -0.0...
# 4      Cricket  [-0.011634827, -0.03463745, -0.0034484863, -0....
#
#     similarity score
# 3           0.656284
# 2           0.629495
# 1           0.618015
# 8           0.589813
# 0           0.544808
# 10          0.523672
# 9           0.516904
# 6           0.447872
# 7           0.441999
# 4           0.425354
