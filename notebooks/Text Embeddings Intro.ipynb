# %% [markdown]
# <font color='green'>
# Pip install is the command you use to install Python packages with the help of a tool called Pip package manager.
# <br><br>Installing LangChain package along with langchain-openai
# </font>

# %%
# !pip install langchain==0.2.5
# !pip install langchain-openai==0.1.9
from dotenv import load_dotenv
import os
# Out:
# Requirement already satisfied: langchain in c:\users\user\anaconda3\lib\site-packages (0.2.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\user\anaconda3\lib\site-packages (from langchain) (4.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\user\anaconda3\lib\site-packages (from langchain) (0.1.81)
# Requirement already satisfied: numpy<2,>=1 in c:\users\user\anaconda3\lib\site-packages (from langchain) (1.23.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from langchain) (2.28.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\user\anaconda3\lib\site-packages (from langchain) (1.10.8)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from langchain) (0.2.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.7 in c:\users\user\anaconda3\lib\site-packages (from langchain) (0.2.9)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\anaconda3\lib\site-packages (from langchain) (3.8.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain) (23.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain) (4.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain) (2.1)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# Requirement already satisfied: langchain-openai in c:\users\user\anaconda3\lib\site-packages (0.1.9)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\user\anaconda3\lib\site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: openai<2.0.0,>=1.26.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-openai) (1.35.3)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-openai) (0.2.9)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (23.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (8.2.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (1.10.8)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (0.1.81)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.3,>=0.2.2->langchain-openai) (6.0)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (0.23.3)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (1.8.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (4.11.0)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (4.65.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.26.0->langchain-openai) (3.5.0)
# Requirement already satisfied: requests>=2.26.0 in c:\users\user\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.28.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\user\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2022.7.9)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.26.0->langchain-openai) (3.4)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain-openai) (2022.12.7)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain-openai) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain-openai) (1.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-openai) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-openai) (3.10.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.1.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.26.0->langchain-openai) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx<1,>=0.23.0->openai<2.0.0,>=1.26.0->langchain-openai) (0.14.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)

# %% [markdown]
# <font color='green'>
# Installing Openai package, which includes the classes that we can use to communicate with Openai services
# <font>

# %%
# !pip install openai==1.35.3
# Out:
# Requirement already satisfied: openai in c:\users\user\anaconda3\lib\site-packages (1.35.3)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\user\anaconda3\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (3.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (1.10.8)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\lib\site-packages (from openai) (4.65.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (0.23.3)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.5.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2022.12.7)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (0.16.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx<1,>=0.23.0->openai) (0.14.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\anaconda3\lib\site-packages)

# %% [markdown]
# ## Let's use OpenAI

# %% [markdown]
# <font color='green'>
# Imports the Python built-in module called "os."
# <br>This module provides a way to interact with the operating system, such as accessing environment variables, working with files and directories, executing shell commands, etc
# <br><br>
# The environ attribute is a dictionary-like object that contains the environment variables of the current operating system session
# <br><br>
# By accessing os.environ, you can retrieve and manipulate environment variables within your Python program. For example, you can retrieve the value of a specific environment variable using the syntax os.environ['VARIABLE_NAME'], where "VARIABLE_NAME" is the name of the environment variable you want to access.
# <font>

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# <font color='green'>
# LangChain has built a Wrapper around OpenAI APIs, using which we can get access to all the services OpenAI provides.
# <br>
# The code snippet below imports a specific class called 'OpenAIEmbeddings'(Wrapper around OpenAI large language models) from the 'embeddings' module of the 'langchain' library.
#
# <font>

# %%
from langchain_openai import OpenAIEmbeddings

# %% [markdown]
# <font color='green'>
# Initialize the OpenAIEmbeddings object
# <font>

# %%
embeddings = OpenAIEmbeddings()

# %%
our_Text = "Hey buddy"

# %%
text_embedding = embeddings.embed_query(our_Text)

# %%
print (f"Our embedding is {text_embedding}")
# Out:
# Our embedding is [-0.009787649847567081, -0.005722643341869116, 0.0016212573973461986, -0.024877207353711128, -0.025067012757062912, 0.012115933932363987, -0.013691321015357971, -0.012071645818650723, -0.010882196016609669, -0.003171337768435478, 0.023776333779096603, -0.026598112657666206, -0.003308946965262294, -0.0005662538460455835, 0.013843165710568428, -0.033228661864995956, 0.04436393082141876, -0.01938549429178238, 0.013678668066859245, -0.004732490051537752, -0.006418597884476185, -0.009540902450680733, -0.002598757157102227, -0.0012693259632214904, -0.015057923272252083, -0.005384156480431557, 0.0028122884687036276, -0.02206808142364025, 0.015766531229019165, -0.0286733228713274, 0.03644270449876785, 0.019056497141718864, -0.018487080931663513, -0.0046502407640218735, -0.029508467763662338, -0.03198859468102455, -0.008073071017861366, -0.011786936782300472, 0.018854038789868355, -0.02621850185096264, 0.029432544484734535, -0.002075209515169263, -0.0